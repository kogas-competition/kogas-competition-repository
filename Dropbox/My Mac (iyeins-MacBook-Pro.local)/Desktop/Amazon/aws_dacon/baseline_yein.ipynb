# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
train = pd.read_csv('/kaggle/input/dacon-jobcare/train.csv')
test = pd.read_csv('/kaggle/input/dacon-jobcare/test.csv')

# %%
train.dtypes

# %%
display(train,test)

# %%
train['contents_attribute_l']

# %%
d_code = pd.read_csv('/kaggle/input/dacon-jobcare/╝╙╝║_D_─┌╡σ.csv', index_col=0).T.to_dict()
h_code = pd.read_csv('/kaggle/input/dacon-jobcare/╝╙╝║_H_─┌╡σ.csv', index_col=0).T.to_dict()
l_code = pd.read_csv('/kaggle/input/dacon-jobcare/╝╙╝║_L_─┌╡σ.csv', index_col=0).T.to_dict()

# %%
# h_code

# %%
all_data = pd.concat([train, test])

# %%
from datetime import datetime
all_data['contents_open_dt'] = pd.to_datetime(all_data['contents_open_dt'])
all_data['contents_open_year'] = all_data['contents_open_dt'].dt.year
all_data['contents_open_month'] = all_data['contents_open_dt'].dt.month

# %%
# D Code
all_data['person_prefer_d_1_n'] = all_data['person_prefer_d_1'].apply(lambda x: d_code[x]['속성 D 세분류코드'])
all_data['person_prefer_d_1_s'] = all_data['person_prefer_d_1'].apply(lambda x: d_code[x]['속성 D 소분류코드'])
all_data['person_prefer_d_1_m'] = all_data['person_prefer_d_1'].apply(lambda x: d_code[x]['속성 D 중분류코드'])
all_data['person_prefer_d_1_l'] = all_data['person_prefer_d_1'].apply(lambda x: d_code[x]['속성 D 대분류코드'])
all_data['person_prefer_d_2_n'] = all_data['person_prefer_d_2'].apply(lambda x: d_code[x]['속성 D 세분류코드'])
all_data['person_prefer_d_2_s'] = all_data['person_prefer_d_2'].apply(lambda x: d_code[x]['속성 D 소분류코드'])
all_data['person_prefer_d_2_m'] = all_data['person_prefer_d_2'].apply(lambda x: d_code[x]['속성 D 중분류코드'])
all_data['person_prefer_d_2_l'] = all_data['person_prefer_d_2'].apply(lambda x: d_code[x]['속성 D 대분류코드'])
all_data['person_prefer_d_3_n'] = all_data['person_prefer_d_3'].apply(lambda x: d_code[x]['속성 D 세분류코드'])
all_data['person_prefer_d_3_s'] = all_data['person_prefer_d_3'].apply(lambda x: d_code[x]['속성 D 소분류코드'])
all_data['person_prefer_d_3_m'] = all_data['person_prefer_d_3'].apply(lambda x: d_code[x]['속성 D 중분류코드'])
all_data['person_prefer_d_3_l'] = all_data['person_prefer_d_3'].apply(lambda x: d_code[x]['속성 D 대분류코드'])
all_data['contents_attribute_d_n'] = all_data['contents_attribute_d'].apply(lambda x: d_code[x]['속성 D 세분류코드'])
all_data['contents_attribute_d_s'] = all_data['contents_attribute_d'].apply(lambda x: d_code[x]['속성 D 소분류코드'])
all_data['contents_attribute_d_m'] = all_data['contents_attribute_d'].apply(lambda x: d_code[x]['속성 D 중분류코드'])
all_data['contents_attribute_d_l'] = all_data['contents_attribute_d'].apply(lambda x: d_code[x]['속성 D 대분류코드'])

all_data['person_prefer_h_1_l'] = all_data['person_prefer_h_1'].apply(lambda x: h_code[x]['속성 H 대분류코드'])
all_data['person_prefer_h_1_m'] = all_data['person_prefer_h_1'].apply(lambda x: h_code[x]['속성 H 중분류코드'])
all_data['person_prefer_h_2_l'] = all_data['person_prefer_h_2'].apply(lambda x: h_code[x]['속성 H 대분류코드'])
all_data['person_prefer_h_2_m'] = all_data['person_prefer_h_2'].apply(lambda x: h_code[x]['속성 H 중분류코드'])
all_data['person_prefer_h_3_l'] = all_data['person_prefer_h_3'].apply(lambda x: h_code[x]['속성 H 대분류코드'])
all_data['person_prefer_h_3_m'] = all_data['person_prefer_h_3'].apply(lambda x: h_code[x]['속성 H 중분류코드'])
all_data['contents_attribute_h_l'] = all_data['contents_attribute_h'].apply(lambda x: h_code[x]['속성 H 대분류코드'])
all_data['contents_attribute_h_m'] = all_data['contents_attribute_h'].apply(lambda x: h_code[x]['속성 H 중분류코드'])

all_data['contents_attribute_l_n'] = all_data['contents_attribute_l'].apply(lambda x: l_code[x]['속성 L 세분류코드'])
all_data['contents_attribute_l_s'] = all_data['contents_attribute_l'].apply(lambda x: l_code[x]['속성 L 소분류코드'])
all_data['contents_attribute_l_m'] = all_data['contents_attribute_l'].apply(lambda x: l_code[x]['속성 L 중분류코드'])
all_data['contents_attribute_l_l'] = all_data['contents_attribute_l'].apply(lambda x: l_code[x]['속성 L 대분류코드'])

# %%
all_data.sample(10)

# %%
import matplotlib.pyplot as plt
plt.hist(all_data['target'])

# %%
all_data2 = all_data.drop(columns=['id','target','contents_open_dt'])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
cat_cols = all_data2.columns[all_data2.dtypes == object]
for col in cat_cols:
    #결측치가 있을 땐 list로 감싸주면 결측치도 하나의 카테고리로 처리됨 
    #column마다 독립적으로 결측치 처리됨 (똑같은 값으로 처리되는 거 아님)
    all_data2[col] = le.fit_transform(list(all_data2[col]))
    
all_data2.dtypes.value_counts()

# %%
train2 = all_data2[:len(train)]
test2 = all_data2[len(train):]

# %%
all_data['target'].nunique()

from xgboost import XGBClassifier
xgb = XGBClassifier(tree_method = 'gpu_hist')
xgb.fit(train2, train['target'])
result = xgb.predict(test2)

# %%
feature_important = xgb.get_booster().get_score(importance_type='weight')
keys = list(feature_important.keys())
values = list(feature_important.values())

data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)
data.nlargest(40, columns="score").plot(kind='barh', figsize = (20,10))

# %%
sub = pd.read_csv('/kaggle/input/dacon-jobcare/sample_submission.csv')
sub

# %%
sub['target'] = result

# %%
sub
sub.to_csv('submission_baseline_month_year.csv', index=False)
